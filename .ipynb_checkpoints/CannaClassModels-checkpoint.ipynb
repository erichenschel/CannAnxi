# %%
# class models:
# Logistic Reg
# Dec. Tree
# Random Forest -- boosting
# SVM
# K-NN
# deep learning --> small amount of data (get as much info as possible)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('cleanData.csv')

# %%
# minor data clean
data = data.drop('Unnamed: 0', axis=1)

# %%
display(data)
# Out:
#     3-Carene   CBDA   CBG  Camphene  CaryophylleneOxide  D-Limonene  \
# 0       0.29    0.0  0.00      0.08                0.00        1.05
# 1       0.35    0.0  0.00      0.04                0.00        1.67
# 2       0.03    0.0  0.00      0.17                0.07        1.30
# 3       0.00   65.0  0.00      0.13                0.00        3.03
# 4       0.00    0.0  0.00      0.13                0.00        2.38
# ..       ...    ...   ...       ...                 ...         ...
# 80      0.00    0.0  0.00      0.00                0.00        0.64
# 81      0.00  115.0  0.00      0.00                0.00        0.00
# 82      0.00    0.0  0.00      0.00                0.00        0.00
# 83      0.00    0.0  1.44      0.00                0.00        4.58
# 84      0.00    0.0  1.06      0.00                0.00        3.47
#
#     Eucalyptol  Geraniol  Guaiol  Isopulegol  ...  TotalCBD  p-Cymene  Δ9-THC  \
# ...

# %%
# data 'eploration'
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   3-Carene            85 non-null     float64
#  1   CBDA                85 non-null     float64
#  2   CBG                 85 non-null     float64
#  3   Camphene            85 non-null     float64
#  4   CaryophylleneOxide  85 non-null     float64
#  5   D-Limonene          85 non-null     float64
#  6   Eucalyptol          85 non-null     float64
#  7   Geraniol            85 non-null     float64
#  8   Guaiol              85 non-null     float64
#  9   Isopulegol          85 non-null     float64
#  10  Label               85 non-null     float64
#  11  Linalool            85 non-null     float64
#  12  Myrcene             85 non-null     float64
#  13  Nerolidol-1         85 non-null     float64
#  14  Nerolidol-2         85 non-null     float64
# ...

# %%
data.describe()
# Out:
#         3-Carene        CBDA        CBG   Camphene  CaryophylleneOxide  \
# count  85.000000   85.000000  85.000000  85.000000           85.000000
# mean    0.039647    7.959765   0.611765   0.033765            0.000824
# std     0.129140   27.729085   0.833438   0.056061            0.007593
# min     0.000000    0.000000   0.000000   0.000000            0.000000
# 25%     0.000000    0.000000   0.000000   0.000000            0.000000
# 50%     0.000000    0.000000   0.000000   0.000000            0.000000
# 75%     0.000000    0.000000   0.980000   0.060000            0.000000
# max     0.710000  127.000000   3.420000   0.240000            0.070000
#
#        D-Limonene  Eucalyptol   Geraniol     Guaiol  Isopulegol  ...  \
# count   85.000000   85.000000  85.000000  85.000000   85.000000  ...
# mean     2.314235    0.010706   0.001882   0.178706    0.005647  ...
# std      1.630993    0.025625   0.017354   0.340765    0.041732  ...
# ...

# %%
# Logistic Regression
